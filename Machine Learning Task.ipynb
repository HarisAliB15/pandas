# %% [markdown]
# <a href="https://colab.research.google.com/github/FarooqKhan456/AI-PYTHON/blob/main/Machine_learning_steps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import accuracy_score

# %%
dataset=pd.read_json('/content/drive/MyDrive/AI Chatbot/bot.json')
dataset
# Out:
#   response_type                            user_input  \
# 0      greeting                      [hello, hi, hey]
# 1      greeting               [see you, goodbye, bye]
# 2      greeting                 [nice, to, meet, you]
# 3      question  [how, to, learn, code, coding, apps]
# 4      question            [refund, how, can, I, get]
# 5      question                       [how, are, you]
#
#                                         bot_response     required_words
# 0                                         Hey there!                 []
# 1                                     See you later!                 []
# 2                          The pleasure is all mine!  [nice, meet, you]
# 3  Start by typing: 'How to learn coding' on Google.      [learn, code]
# 4         We don't offer refunds for free education.        [refund, i]
# 5                      I'm great! Thanks for asking.    [how, are, you]

# %%
label =LabelEncoder()
label.fit(dataset.bot_response.drop_duplicates())
dataset.bot_response=label.transform(dataset.bot_response)

dataset
# Out:
#   response_type                            user_input  bot_response  \
# 0      greeting                      [hello, hi, hey]             0
# 1      greeting               [see you, goodbye, bye]             2
# 2      greeting                 [nice, to, meet, you]             4
# 3      question  [how, to, learn, code, coding, apps]             3
# 4      question            [refund, how, can, I, get]             5
# 5      question                       [how, are, you]             1
#
#       required_words
# 0                 []
# 1                 []
# 2  [nice, meet, you]
# 3      [learn, code]
# 4        [refund, i]
# 5    [how, are, you]

# %%
import pandas as pd
df = pd.DataFrame({"a": [1,2,3], "b":[2,4,6]})
print("The DataFrame object before deleting the column")
print(df)
df.drop('a', inplace=True, axis=1)
print("The DataFrame object after deleting the column a")
print(df)
# Out:
# The DataFrame object before deleting the column
#    a  b
# 0  1  2
# 1  2  4
# 2  3  6
# The DataFrame object after deleting the column a
#    b
# 0  2
# 1  4
# 2  6
